# %% [markdown]
# ### The die exercise

# %%
# Create the die class

from random import randint
class Die:
    """A class representing a single die."""
    
    def __init__(self, num_sides=6):
        """Assume a six-sided die."""
        
        self.num_sides = num_sides
    def roll(self):
        """"Return a random value between 1 and number of sides."""
        return randint(1, self.num_sides)

# %%
# Create a D6.

die = Die()

# Make some rolls, and store results in a list.
results = []

for roll_num in range(100):
    result = die.roll()
    results.append(result)
    
print(results)
# Out:
# [5, 3, 1, 3, 1, 2, 1, 2, 4, 3, 1, 6, 2, 6, 5, 2, 1, 5, 5, 2, 5, 5, 6, 4, 4, 5, 5, 6, 1, 5, 6, 3, 1, 2, 3, 3, 3, 3, 5, 1, 1, 6, 6, 5, 4, 3, 2, 1, 3, 3, 2, 3, 4, 3, 6, 5, 5, 6, 3, 5, 5, 2, 6, 5, 5, 6, 4, 3, 1, 6, 2, 3, 5, 4, 5, 2, 6, 6, 4, 6, 6, 2, 2, 2, 2, 1, 2, 3, 2, 6, 4, 4, 1, 2, 6, 3, 3, 1, 3, 6]

# %%
# Make some rolls, and store results in a list.
results = []

for roll_num in range(1000):
    result = die.roll()
    results.append(result)

# Analyze the results.
frequencies = []

poss_results = range(1, die.num_sides+1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)

print(frequencies)
# Out:
# [165, 167, 178, 167, 165, 158]

# %%
import pandas as pd

# Sample data
poss_results = [x for x in poss_results]
frequencies 

# Visualize the results
fig = pd.DataFrame({'poss_results': poss_results, 'frequencies': frequencies}).plot.bar(x='poss_results', y='frequencies')

# %% [markdown]
# #### Rolling two dies

# %%
# Create two D6 dice.
die_1 = Die()
die_2 = Die()

# Make some rolls, and store results in a list.
results = []
for roll_num in range(1000):
    result = die_1.roll() + die_2.roll()
    results.append(result)

# Analyze the results.
frequencies = []

max_result = die_1.num_sides + die_2.num_sides
poss_results = range(2, max_result+1)

for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)
    

print()
print(frequencies)
# Out:
# [32, 46, 85, 113, 125, 177, 134, 116, 87, 64, 21]

# %%
# Visualize the results.

import pandas as pd
import matplotlib.pyplot as plt



# Sample data
poss_results = [x for x in poss_results]


# Create DataFrame
df = pd.DataFrame({'poss_results': poss_results, 'frequencies': frequencies})

# Plot
ax = df.plot.bar(x='poss_results', y='frequencies', legend=False)

# Add title and labels
plt.title("Results of Rolling Two D6 Dice 1,000 Times")
plt.xlabel('Results')
plt.ylabel('Frequency of Result')

# Show plot
plt.show()
